# %% [markdown]
# # 🛠️ 開発ログ：2025年6月1日（日）
#
# ## ✅ 今日の目標（作業時間：約1時間想定）
# - チャット機能の基盤強化（エンティティの整理と関係構築）
# - WebSocket周りの確認と安定化
#
# ---
#
# ## 📋 今日やることリスト
#
# ### 🔧 エンティティ構成調整
# - [✅] `ChatRoom` エンティティの作成・導入
# - [✅] `Message` に `@ManyToOne` で `ChatRoom` を紐付け
# - [✅] `MessageController` の `roomId` 参照ロジックを `ChatRoom` 経由に書き換え
#
# ### 🔍 WebSocketの確認
# - [✅] STOMPクライアントが接続されているか確認（`useEffect` 内でログ出力あり）
# - [✅] WebSocket 経由でメッセージが反映されることを確認
#
# ---
#
# ## 📝 明日以降の予定候補
# - [ ] メッセージ送信時のバリデーション強化（空送信防止など）
# - [ ] ユーザーによる投稿削除・編集機能（UIボタンとAPIの追加）
# - [ ] ユーザー削除時の連動削除処理（外部キー制約 or ソフトデリート）
# - [ ] チャット一覧に最新メッセージのプレビュー表示
# - [ ] モバイル最適化（レスポンシブ調整）
