# %% [markdown]
# # 🛠️ 開発ログ：2025年4月8日（火）
#
# ## ✅ 今日の目標（21:00〜22:00）
# - 主要な画面のワイヤーフレームを作成して、基本的な画面構成と遷移を把握する
#
# ---
#
# ## 📋 今日やることリスト（1時間想定）
#
# ### ① ワイヤーフレーム作成（使用ツール：draw.io）
#
# - [✅] ログイン画面（ユーザー名・パスワード入力＋ボタン）
# - [✅] チャットルーム一覧画面（ルーム名一覧＋ルーム作成ボタン）
# - [✅] チャット画面（メッセージ履歴＋入力欄＋送信ボタン）
# - [✅] 各画面のつながり（遷移）を矢印で表現
#
# ---
#
# ## ⏳ 残りは明日以降にやる！
#
# - [ ] アカウント表示ポップアップ
# - [ ] ルーム作成画面
# - [ ] 画面の細かいデザイン調整（余白やボタン位置など）
#
# ---
#
# ## 📝 メモ・気づき
#
# - ルーム削除ボタンの追加
# -
# -
#
# ---
#
# ## ⏭ 明日以降のタスク候補（4/9以降）
#
# - DB構成の最終チェック（users / chat_rooms / messages）
# - ER図作成（draw.io）
# - 技術スタック確定（React or Vue / PostgreSQL）
# - Spring Bootのプロジェクト雛形作成（start.spring.io）
