# %% [markdown]
# # 🛠️ 開発ログ：2025年4月7日（月）
#
# ## ✅ 今日の目標
# - チャットアプリの機能と設計を明確にし、実装の土台を作る
#
# ---
#
# ## 📋 今日やることリスト
#
# ### ① 機能要件の再確認（15分）
# - [✅] 必須機能・非機能の見直し
#   - ログイン、ログアウト、メッセージ送信機能、メッセージ受信機能、通知
# - [✅] 追加したい機能（既読表示機能、メッセージ削除機能、チャットルーム作成機能、チャットルーム一覧、返信機能、メンション）を検討
#
# ### ② 画面構成のアイデア出し（30〜60分）
# - [✅] 必要な画面を洗い出す
#   - ログイン画面
#   - ログアウト画面
#   - チャットルーム一覧
#   - チャット画面
#   - ルーム作成
#   - アカウント表示画面(ポップアップ程度)
# - [ ] ワイヤーフレーム作成
#   - 使用ツール：draw.io など
#
# ### ③ DB設計の確認とER図作成（30分）
# - [ ] テーブル構成（users / chat_rooms / messages）を確認
# - [ ] ER図作成（ツール：draw.io）
# - [ ] JOINを使ったデータ取得のイメージも確認
#
# ### ④ 技術スタックの最終確認（15分）
# - [ ] フロントエンド：React / Vue / Vanilla JS の選定
# - [ ] DB：PostgreSQL / MySQL の選定
# - [ ] Spring Bootに含める機能の確認（WebSocket, JPA など）
#
# ---
#
# ## 📝 メモ・気づき
# -
# -
# -
#
# ---
#
# ## ⏳ 明日以降のタスク候補
# - Spring Bootプロジェクトの雛形作成（start.spring.io）
# - ER図を元にエンティティクラス作成
# - 環境構築（DB / 開発サーバー / Git リポジトリ）
