# %% [markdown]
# # 🛠️ 開発ログ：2025年4月13日（土）
#
# ## ✅ 今日の目標（作業時間：約3時間）
# ReactとSpring Bootを接続し、ログイン機能を完成させる！
#
# ---
#
# ## 📋 今日やることリスト
#
# ### ① React側のログイン処理（〜1時間）
# - [✅] ボタン押下時に `console.log()` で入力確認
# - [✅] `fetch()` または `axios` で `/login` API に POST 送信
# - [ ] 空欄チェックなどの簡単なバリデーション
#
# ---
#
# ### ② Spring Boot 側のAPI作成（〜1時間）
# - [✅] `LoginController.java` の作成（`@PostMapping("/login")`）
# - [ ] `UserService` でDBのユーザーとパスワード照合
# - [✅] 認証OKなら `ログイン成功`、失敗なら `401 Unauthorized` を返す
#
# ---
#
# ### ③ フロントと連携・画面遷移（〜1時間）
# - [✅] レスポンス内容をReactで受け取り、メッセージ表示
# - [ ] ログイン成功時にチャット画面へ遷移（`useNavigate()` 使用）
# - [ ] `react-router-dom` を導入してルーティング設定
#
# ---
#
# ## 🧠 補足タスク（余裕あれば）
# - [ ] ログイン中ボタンを無効化（ローディング状態）
# - [✅] ログイン失敗時のエラーメッセージ表示
# - [ ] ログイン状態の保持（`localStorage` or `useContext`）
#
# ---
#
# ## ⏳ タイムガイド（目安）
#
# | 内容 | 時間配分 |
# |------|----------|
# | フロント処理（入力 → API呼び出し） | 1時間 |
# | バックエンド処理（認証ロジック） | 1時間 |
# | 接続確認と画面遷移処理 | 1時間 |
#
# ---
#
# ## 💬 今日のメモ・気づき
#
# - Spring Boot 側の `package` にアンダースコアが入っていて、起動できなかった → `package com.example.chatapp;` に修正して解決
# - `fetch()` のURLは `"http://localhost:8080/login"` でないと通信が通らず、意外とハマりポイントだった。
#
# ---
